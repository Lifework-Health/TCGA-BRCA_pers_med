# %% [markdown]
# # 06 Question 6: LINCS Signature
#
# This notebook will eventually use LINCS perturbation signatures to connect doxorubicin response with p53 and DNA-damage response biology.
#
# No LINCS analysis is implemented yet.

# %% [markdown]
# ## Planned Analysis
#
# - Identify relevant doxorubicin or DNA-damage perturbation signatures.
# - Compare LINCS gene-expression changes with p53 and DNA-damage response features.
# - Relate perturbation signatures back to TCGA-BRCA and cell-line analyses.

# %% [markdown]
# ## Interpretation Plan
#
# The final notebook should explain whether LINCS signatures support the biological story from the patient, cell-line, and ODE analyses.
